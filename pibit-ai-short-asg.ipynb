# %% [markdown]
# ### Short Assignment:
# - Write a ChatGPT Prompt which takes your Resume as input and parse the content in JSON format. Share Github Link of the solution if possible.

# %%
Resume='''
        
Prafull Sonawane
   https://github.com/prafuel    https://www.linkedin.com/in/prafull-sonawane # official.sonawaneprafull@gmail.com

Projects

Credit Risk Assesment Modeling | Python, Pandas, Numpy, Matplotlib, Seaborn, Sklearn, Jupyter-notebook, Streamlit
    Developed a loan classification system to categorize customers based on their loan repayment records into
classifications such as P1 (most ideal customer), P2 (less ideal), P3, and P4. Tested various classification models
including Logistic Regression, Decision Tree, and Random Forest.

    Followed a comprehensive ML project lifecycle, including Data Preprocessing, Data Cleaning, EDA, and Feature
Engineering. Cleaned the data extensively using pandas method chaining to handle numerous null values and
incorrect data types.

    After training various model using Logistic Regression achieved 0.98 accuracy and 0.97 f1-score on unseen testing
data

Good Prompt | Langchain, LLM, MongoDB, Flask, Nextjs, Tailwind, Git, Jupyter-notebook, AWS
    Solution for the LLM text segmentation issue by using prompt engineering and Retrieval-Augmented Generation
(RAG) for specific information. Data is stored in MongoDB.

    Learned how to integrate a Next.js frontend with MongoDB through an API and deploy an LLM model on a Flask
server.

    Implemented robust backend logic to handle complex data queries and ensure efficient data retrieval, enhancing the
overall performance and scalability of the application.

Text Analytics on MAMA EARTH Dataset | Streamlit, Pandas, Numpy, Plotly, Git, VS Code
    TensorFiesta (Hackathon) based on Text Analytics (1st Runner-up)
    Developed a Streamlit app for market analysis based on sold products, predicting future high-demand products,
and suggesting strategies. Required extensive data cleaning and EDA, including changing data types (e.g., object to
number), removing commas, and cleaning irregular strings in the reviews feature.

    Learned how to create and interpret various plots such as scatter plots, line charts, and pie charts to retrieve
insights. Identified business use cases, such as the significant difference between solo products and combos, with
solo products having a higher sell rate due to less required space and better reviews.

Skills

Languages: C/C++, Python, Java, JavaScript

Framework: Nextjs, Tailwind, Flask

Libraries: Numpy, Pandas, Sklearn, Matplotlib, Seaborn, Plotly, Streamlit

Databases: Mysql, MongoDB, AWS

Tools: Linux, Git/GitHub, Docker, Jupyter-notebook

Education

MJ Junior Collage of Science, Commarce and Arts, jalgaon June 2021
12th Percentage : 82.4

Vishwakarma Institude of Technology, pune Expected to Graduate 2025
Btech - Artificial Intelligence and Data Science Current CGPA : 8.3

Extracurricular

Computer Society of India (CSI Student Chapter) | Multimedia Coordinator 2022     2023
Involved in the club centered Technical Events, main work is to handle all the social media post

Ekasutram | Multimedia Coordinator 2022     2023
Worked as Multimedia Coordinator, handle all the poster making and designing grids on social handles

https://github.com/prafuel
https://www.linkedin.com/in/prafull-sonawane/
mailto:official.sonawaneprafull@gmail.com
https://github.com/prafuel/credit-risk-assesment-modeling
https://github.com/prafuel/good-prompt-frontend
https://github.com/prafuel/TensorFiesta_Hackathon

	Projects
	Skills
	Education
	Extracurricular
'''

# %%
Resume={Resume} ,Given Candidate of Resume your task is to extract information from following resume 
        and give me result in json format eg. {
    'name' : <user_name>,
    'info' : [<collage_name>, <email>, <linkedin>, <links in resumes>...],
    'skills' : <skills and techical knowledge use had in list format...>,
    'projects_desc' : [<list of project each element is dict and contain 
                {'project_name' : <proj_name>, 
                'one_line_summary' : <one line summary about this project>} 
                ...>]
}

# %% [markdown]
# ### Output
# <img src='./result.png'/>

# %%
result = {
    "name": "Prafull Sonawane",
    "info": {
        "college_name": "Vishwakarma Institute of Technology, Pune",
        "email": "official.sonawaneprafull@gmail.com",
        "linkedin": "https://www.linkedin.com/in/prafull-sonawane",
        "github": "https://github.com/prafuel",
        "links": [
            "https://github.com/prafuel/credit-risk-assesment-modeling",
            "https://github.com/prafuel/good-prompt-frontend",
            "https://github.com/prafuel/TensorFiesta_Hackathon"
        ]
    },
    "skills": [
        "C/C++",
        "Python",
        "Java",
        "JavaScript",
        "Nextjs",
        "Tailwind",
        "Flask",
        "Numpy",
        "Pandas",
        "Sklearn",
        "Matplotlib",
        "Seaborn",
        "Plotly",
        "Streamlit",
        "Mysql",
        "MongoDB",
        "AWS",
        "Linux",
        "Git/GitHub",
        "Docker",
        "Jupyter-notebook"
    ],
    "projects_desc": [
        {
            "project_name": "Credit Risk Assessment Modeling",
            "one_line_summary": "Developed a loan classification system using various classification models including Logistic Regression, Decision Tree, and Random Forest, achieving 0.98 accuracy and 0.97 f1-score on unseen testing data."
        },
        {
            "project_name": "Good Prompt",
            "one_line_summary": "Solved LLM text segmentation issue using prompt engineering and Retrieval-Augmented Generation, integrating Next.js frontend with MongoDB through an API and deploying an LLM model on a Flask server."
        },
        {
            "project_name": "Text Analytics on MAMA EARTH Dataset",
            "one_line_summary": "Developed a Streamlit app for market analysis, predicting future high-demand products, and suggesting strategies, achieving 1st Runner-up in TensorFiesta Hackathon."
        }
    ]
}
